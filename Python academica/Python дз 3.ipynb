# %%
movie_dict = {'Name' : 'Social media', 'Year' : 2010, 'Genre' : 'Action', 'Director' : 'Ronaldo'}

# %%
movie_dict['Actor'] = 'Tony Stark'

# %%
movie_dict
# Out:
# {'Name': 'Social media',
#  'Year': 2010,
#  'Genre': 'Action',
#  'Director': 'Ronaldo',
#  'Actor': 'Tony Stark'}

# %%
tup = (1, 'People', True)
print(tup[0], type(tup[0]))
print(tup[1], type(tup[1]))
print(tup[2], type(tup[2]))
# Out:
# 1 <class 'int'>
# People <class 'str'>
# True <class 'bool'>

# %%
num = int(input('Введите ваше число: '))
if num % 2 == 0:
          print('Ваше число четное')
else:
          print('Ваше число нечетное')
# Out:
# Введите ваше число:  8
# Ваше число четное

# %%
name = input('Введите ваше имя: ')
color = input('Ваш любимый цвет: ')
print(f'Привет, {name}. Ваш любимый цвет {color}')
# Out:
# Введите ваше имя:  Alish
# Ваш любимый цвет:  dark purple
# Привет, Alish. Ваш любимый цвет dark purple
