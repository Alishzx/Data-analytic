# %%
boxer = ['Golovkin', 'Canelo', 'Garcia', 'Usyk']
print(f'Я хотел бы увидеться с {boxer[0]}')
print(f'Я хотел бы увидеться с {boxer[1]}')
print(f'Я хотел бы увидеться с {boxer[2]}')
print(f'Я хотел бы увидеться с {boxer[3]}')
# Out:
# Я хотел бы увидеться с Golovkin
# Я хотел бы увидеться с Canelo
# Я хотел бы увидеться с Garcia
# Я хотел бы увидеться с Usyk

# %%
guests = ['Кайрат', 'Айжан', 'Айдын']
print(f'Приглашаю тебя, {guests[0]}, на обед')
print(f'Приглашаю тебя, {guests[1]}, на обед')
print(f'Приглашаю тебя, {guests[2]}, на обед')
# Out:
# Приглашаю тебя, Кайрат, на обед
# Приглашаю тебя, Айжан, на обед
# Приглашаю тебя, Айдын, на обед

# %%
guests = ['Кайрат', 'Айжан', 'Айдын']
guests.insert(0,'Арман')
guests.append('Айтолкын')
guests.insert(2,'Канат')
print(f'«Приглашаю тебя, {guests[0]}, на обед»')
print(f'«Приглашаю тебя, {guests[1]}, на обед»')
print(f'«Приглашаю тебя, {guests[2]}, на обед»')
print(f'«Приглашаю тебя, {guests[3]}, на обед»')
print(f'«Приглашаю тебя, {guests[4]}, на обед»')
print(f'«Приглашаю тебя, {guests[5]}, на обед»')
# Out:
# «Приглашаю тебя, Арман, на обед»
# «Приглашаю тебя, Кайрат, на обед»
# «Приглашаю тебя, Канат, на обед»
# «Приглашаю тебя, Айжан, на обед»
# «Приглашаю тебя, Айдын, на обед»
# «Приглашаю тебя, Айтолкын, на обед»

# %%
guests_pop = guests.pop(-1)
print(f'«Сожалею об отмене приглашения, {guests_pop}, на обед»')
guests_pop = guests.pop(-1)
print(f'«Сожалею об отмене приглашения, {guests_pop}, на обед»')
guests_pop = guests.pop(-1)
print(f'«Сожалею об отмене приглашения, {guests_pop}, на обед»')
guests_pop = guests.pop(-1)
print(f'«Сожалею об отмене приглашения, {guests_pop}, на обед»')
# Out:
# «Сожалею об отмене приглашения, Айтолкын, на обед»
# «Сожалею об отмене приглашения, Айдын, на обед»
# «Сожалею об отмене приглашения, Айжан, на обед»
# «Сожалею об отмене приглашения, Канат, на обед»

# %%
country = ['Japan', 'USA', 'Saudi Arabi', 'South Korea', 'China']
print(country)
print(sorted(country))
print(country)
country.sort(reverse = 1)
print(country)
# Out:
# ['Japan', 'USA', 'Saudi Arabi', 'South Korea', 'China']
# ['China', 'Japan', 'Saudi Arabi', 'South Korea', 'USA']
# ['Japan', 'USA', 'Saudi Arabi', 'South Korea', 'China']
# ['USA', 'South Korea', 'Saudi Arabi', 'Japan', 'China']
